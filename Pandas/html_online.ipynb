# %%
import lxml
import pandas as pd

# %%
df1 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(df1)
# Out:
# list

# %%
len(df1)
# Out:
# 1

# %%
df1[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df3=df1[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df3.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3.head(50)
# Out:
#     Rk                 Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0    1             Quincy Acy   PF   24  NYK  68  22  1287  152   331  ...
# 1    2           Jordan Adams   SG   20  MEM  30   0   248   35    86  ...
# 2    3           Steven Adams    C   21  OKC  70  67  1771  217   399  ...
# 3    4            Jeff Adrien   PF   28  MIN  17   0   215   19    44  ...
# 4    5          Arron Afflalo   SG   29  TOT  78  72  2502  375   884  ...
# 5    5          Arron Afflalo   SG   29  DEN  53  53  1750  281   657  ...
# 6    5          Arron Afflalo   SG   29  POR  25  19   752   94   227  ...
# 7    6          Alexis Ajinça    C   26  NOP  68   8   957  181   329  ...
# 8    7         Furkan Aldemir   PF   23  PHI  41   9   540   40    78  ...
# 9    8           Cole Aldrich    C   26  NYK  61  16   976  144   301  ...
# 10   9      LaMarcus Aldridge   PF   29  POR  71  71  2512  659  1415  ...
# ...

# %%
df3.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df3.tail(30)
# Out:
#       Rk           Player  Pos  Age   Tm   G  GS    MP   FG  FGA  ...    FT%  \
# 645  477  Elliot Williams   SG   25  TOT  13   0   119   14   37  ...   .250
# 646  477  Elliot Williams   SG   25  UTA   5   0    42    6   13  ...   .500
# 647  477  Elliot Williams   SG   25  NOP   8   0    77    8   24  ...   .000
# 648  478     Lou Williams   SG   28  TOR  80   0  2016  375  928  ...   .861
# 649  479  Marvin Williams   PF   28  CHO  78  37  2035  210  495  ...   .713
# 650  480      Mo Williams   PG   32  TOT  68  33  1980  341  860  ...   .872
# 651  480      Mo Williams   PG   32  MIN  41  19  1149  180  447  ...   .851
# 652  480      Mo Williams   PG   32  CHO  27  14   831  161  413  ...   .892
# 653   Rk           Player  Pos  Age   Tm   G  GS    MP   FG  FGA  ...    FT%
# 654  481  Reggie Williams   SF   28  SAS  20   0   105   15   39  ...  1.000
# 655  482  Shawne Williams   SF   28  TOT  63  22  1087  121  300  ...   .875
# ...

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
list(df3.columns)
# Out:
# ['Rk',
#  'Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
type(df3.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3['3PA']
# Out:
# 0       60
# 1       25
# 2        2
# 3        0
# 4      333
#       ...
# 670    115
# 671     65
# 672     50
# 673      1
# 674      0
# Name: 3PA, Length: 675, dtype: object

# %%
type(df3['3PA'])
# Out:
# pandas.core.series.Series

# %%
df3[['3PA','PF']]
# Out:
#      3PA   PF
# 0     60  147
# 1     25   24
# 2      2  222
# 3      0   30
# 4    333  167
# ..   ...  ...
# 670  115  171
# 671   65  115
# 672   50   56
# 673    1  156
# 674    0  205
#
# [675 rows x 2 columns]

# %%
df3.to_csv("onlinehtml_data.csv",index=False)
