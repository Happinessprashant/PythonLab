# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashantjadhav2620/PythonLab/blob/prashant/bokeh_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
# !pip install bokeh

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers


output_file("test.html")

p = figure(title="test flower")
p.xaxis.axis_label = "petal length"
p.yaxis.axis_label = "petal width"
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="b232ca9f-75ba-46e2-88bd-c7e501737141" data-root-id="p1102" style="display: contents;"></div>

# %%
output_file("line.html")

p = figure(title="Line Graph")
p.xaxis.axis_label = "x-axis"
p.yaxis.axis_label = "y-axis"
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="af39616b-c4ad-4d3f-8879-e53b09a68ad4" data-root-id="p1145" style="display: contents;"></div>

# %%
x=[2,3,4,5,6]
y=[3,4,5,6,7]
output_file("self.html")

p = figure(title="doted Graph x/y")
p.scatter(x,y,fill_color='red')
show(p)
# Out:
#   <div id="fdbeb5b5-66c5-4c3f-847a-c6bbd57b941d" data-root-id="p1227" style="display: contents;"></div>

# %%
x=[2,3,4,5,6]
y=[3,4,5,6,7]
output_file("self.html")

p = figure(title="Line Graph x/y")
p.line(x,y)
show(p)
# Out:
#   <div id="d92bab5e-4590-4da9-9215-cfddc0204d17" data-root-id="p1299" style="display: contents;"></div>

# %%
x=[2,3,4,5,6]
y=[3,4,5,6,7]
output_file("self.html")

p = figure(title="Line Graph x/y")
p.line(x,y , color="red")
show(p)
# Out:
#   <div id="c7526bdb-25f2-4047-9e6b-592ad395fe9a" data-root-id="p1338" style="display: contents;"></div>

# %%
x=[2,3,4,5,6]
y=[3,4,5,6,7]
output_file("self.html")

p = figure(title="doted Graph x/y")
p.scatter(x,y,fill_color='red', legend_label= "red points")
show(p)
# Out:
#   <div id="b24a9ff8-97de-4e26-a0b6-36910e3da945" data-root-id="p1377" style="display: contents;"></div>

# %%
x=[2,3,4,5,6]
y=[3,4,5,6,7]
output_file("self.html")

p = figure(title="doted Graph x/y")
p.scatter(x,y,fill_color='red', legend_label= "red points",  size=20)
show(p)
# Out:
#   <div id="e914976d-3602-41f7-a054-496d748f931e" data-root-id="p1418" style="display: contents;"></div>

# %%
x=[2,6,4,5,6]
y=[3,4,5,6,7]
output_file("self.html")

p = figure(title="doted Graph x/y")
p.scatter(x,y,fill_color='red', legend_label= "red points" , size=10)
show(p)
# Out:
#   <div id="b0db490d-e35d-4950-83ac-07588a8ba72f" data-root-id="p1459" style="display: contents;"></div>

# %%
x=[2,8,4,5,6]
y=[3,4,5,6,7]
output_file("self.html")

p = figure(title="Line Graph x/y")
p.line(x,y , color="red")
show(p)
# Out:
#   <div id="bfed7fd0-0d34-4b55-807a-744ce07b199d" data-root-id="p1500" style="display: contents;"></div>
